# %% [markdown]
# # Mini block Cipher Implementation
# ## Primitives

# %%
# Mini Block Cipher Implementation and Meet-in-the-Middle Attack

# --- Task 1: Implementing Mini Block Cipher ---

# Key Expansion: Split 16-bit key into Key0, Key1, Key2
def key_expansion(key):
    Key0 = (key >> 8) & 0xFF  # First 8 bits
    Key1 = key & 0xFF        # Next 8 bits
    Key2 = Key0 ^ Key1        # XOR of Key0 and Key1 (example)
    return Key0, Key1, Key2

# Substitution function (example: simple XOR with a constant)
# Create s-box (nib) table and the inverse
s_box = {
    0b0000: 0b1001,
    0b0001: 0b0100,
    0b0010: 0b1010,
    0b0011: 0b1011,
    0b0100: 0b1101,
    0b0101: 0b0001,
    0b0110: 0b1000,
    0b0111: 0b0101,
    0b1000: 0b0110,
    0b1001: 0b0010,
    0b1010: 0b0000,
    0b1011: 0b0011,
    0b1100: 0b1100,
    0b1101: 0b1110,
    0b1110: 0b1111,
    0b1111: 0b0111
}

inverse_s_box = {v: k for k, v in s_box.items()}

def substitute(state, inverse=False):
    n0 = (state >> 12) & 0x0F
    n1 = (state >> 8) & 0x0F
    n2 = (state >> 4) & 0x0F
    n3 = state & 0x0F
    if inverse:  # Reverse substitution (16-bit constant)
        s0 = inverse_s_box[n0]
        s1 = inverse_s_box[n1]
        s2 = inverse_s_box[n2]
        s3 = inverse_s_box[n3]
        return (s0 << 12) | (s1 << 8) | (s2 << 4) | s3
    else:  # Forward substitution (16-bit constant)
        s0 = s_box[n0]
        s1 = s_box[n1]
        s2 = s_box[n2]
        s3 = s_box[n3]
        return (s0 << 12) | (s1 << 8) | (s2 << 4) | s3

# Shift function (example: circular shift left by 4 bits)
# Since we are only swapping bottom row, there is no inverse shift
def shift(state, inverse=False):
    k0 = (state >> 12) & 0x0F
    k2 = (state >> 4) & 0x0F
    k1 = state & 0x0F
    k3 = (state >> 8) & 0x0F
    return (k0 << 12) | (k1 << 8) | (k2 << 4) | k3

# Mix function (example: XOR with a constant)
# XOR is it's own inverse
def mix(state, inverse=False):
    n0 = (state >> 12) & 0x0F
    n1 = (state >> 8) & 0x0F
    n2 = (state >> 4) & 0x0F
    n3 = state & 0x0F
    mixed_cols = 0x0
    for i, c in enumerate([n0 << 4 | n1, n2 << 4 | n3]):
        b0 = ((c & 0x10000000) >> 7) & 0x0F
        b1 = ((c & 0x01000000) >> 6) & 0x0F
        b2 = ((c & 0x00100000) >> 5) & 0x0F
        b3 = ((c & 0x00010000) >> 4) & 0x0F
        b4 = ((c & 0x00001000) >> 3) & 0x0F
        b5 = ((c & 0x00000100) >> 2) & 0x0F
        b6 = ((c & 0x00000010) >> 1) & 0x0F
        b7 = ((c & 0x00000001) >> 0) & 0x0F
        m0 = b0 ^ b6
        m1 = b1 ^ b4 ^ b7
        m2 = b2 ^ b4 ^ b5
        m3 = b3 ^ b5
        m4 = b2 ^ b4
        m5 = b0 ^ b3 ^ b5
        m6 = b0 ^ b1 ^ b6
        m7 = b1 ^ b7
        mixed_cols = mixed_cols << 8 | (m0 << i+7) | (m1 << i+6) | (m2 << i+5) | (m3 << i+4) | (m4 << i+3) | (m5 << i+2) | (m6 << i+1) | m7 << i+0
        return mixed_cols

# %% [markdown]
# ### Test primitives
# Using values from the slides

# %%
# Key Expansion
k = 0b0101100101111010
k0, k1, k2 = key_expansion(k)

print(f'k0: {k0:08b}, k1: {k1:08b}, k2: {k2:08b}')
assert k0 == 0b01011001
assert k1 == 0b01111010
assert k2 == k0 ^ k1
# Out:
# k0: 01011001, k1: 01111010, k2: 00100011

# %%
# Substitution
k = 0b0000001100111001
s = substitute(k)

print(f'state     : {k:016b}')
print(f'substitute: {s:016b}')
assert s == 0b1001101110110010
# Out:
# state     : 0000001100111001
# substitute: 1001101110110010

# %%
# Shift row
k = 0b0000001100111001
s = substitute(k)
sr = shift(s)

print(f'k     : {k:016b}')
print(f's     : {s:016b}')
print(f'shift : {sr:016b}')
assert sr == 0b1001001010111011
# Out:
# k     : 0000001100111001
# s     : 1001101110110010
# shift : 1001001010111011

# %%
# Mix columns
k = 0b0000001100111001
s = substitute(k)
sr = shift(s)
m = mix(sr)
print(f'shift : {sr:016b}')
print(f'mix   : {m:016b}')
assert m == 0b0001000000010001
# Out:
# shift : 1001001010111011
# mix   : 0000010000010000
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[39], line 8
#       6 print(f'shift : {sr:016b}')
#       7 print(f'mix   : {m:016b}')
# ----> 8 assert m == 0b0001000000010001
#
# AssertionError:

# %% [markdown]
# ## Encryption Functions

# %%
# AddRoundKey function (XOR with the round key)
def add_round_key(state, round_key):
    return state ^ round_key

# Encryption Round 1
def encrypt_round1(state, Key1):
    state = substitute(state)
    state = shift(state)
    state = mix(state)
    state = add_round_key(state, Key1)
    return state

# Encryption Round 2
def encrypt_round2(state, Key2):
    state = substitute(state)
    state = shift(state)
    state = add_round_key(state, Key2)
    return state

# Decryption Round 2
def decrypt_round2(state, Key2):
    state = add_round_key(state, Key2)
    state = shift(state, inverse=True)
    state = substitute(state, inverse=True)
    return state

# Decryption Round 1
def decrypt_round1(state, Key1):
    state = add_round_key(state, Key1)
    state = mix(state, inverse=True)
    state = shift(state, inverse=True)
    state = substitute(state, inverse=True)
    return state

# Full Encryption
def encrypt(plaintext, key):
    Key0, Key1, Key2 = key_expansion(key)
    state = plaintext ^ Key0  # Initial AddRoundKey
    state = encrypt_round1(state, Key1)
    state = encrypt_round2(state, Key2)
    return state

# Full Decryption
def decrypt(ciphertext, key):
    Key0, Key1, Key2 = key_expansion(key)
    state = decrypt_round2(ciphertext, Key2)
    state = decrypt_round1(state, Key1)
    state = state ^ Key0  # Final AddRoundKey
    return state

# %% [markdown]
# # Implmentation

# %%
# Generate Plaintext-Ciphertext Pairs
key = 0b1010101010101010
plaintext_ciphertext_pairs = []
for i in range(10):
    plaintext = i * 0b1100110011001100
    ciphertext = encrypt(plaintext, key)
    plaintext_ciphertext_pairs.append((plaintext, ciphertext))

print("Plaintext-Ciphertext Pairs:")
for p, c in plaintext_ciphertext_pairs:
    print(f"Plaintext: {p:016b}, Ciphertext: {c:016b}")

# --- Task 2: Meet-in-the-Middle Attack ---

def meet_in_the_middle(plaintext_ciphertext_pairs):
    (plaintext1, ciphertext1), (plaintext2, ciphertext2) = plaintext_ciphertext_pairs[:2] #use the first two pairs.

    forward_table = {}
    for key1 in range(256):  # Key1 is 8 bits
        intermediate = encrypt_round1(plaintext1, key1)
        forward_table[intermediate] = key1

    reverse_table = {}
    for key2 in range(256):  # Key2 is 8 bits
        intermediate = decrypt_round2(ciphertext1, key2)
        if intermediate in forward_table:
            reverse_table.setdefault(intermediate, []).append(key2)

    possible_keys = []
    for intermediate, key1 in forward_table.items():
        if intermediate in reverse_table:
            for key2 in reverse_table[intermediate]:
                # Verify with the second pair
                if encrypt_round2(encrypt_round1(plaintext2, key1), key2) == ciphertext2:
                    possible_keys.append((key1, key2))

    return possible_keys

possible_keys = meet_in_the_middle(plaintext_ciphertext_pairs)
print("\nPossible Key Pairs:")
for k1, k2 in possible_keys:
    print(f"Key1: {k1:08b}, Key2: {k2:08b}")

# --- Task 3: Analysis ---

# a) Key Space
key_space = 2**16
print(f"\nKey Space: {key_space}")

# b) Double Mini Block Cipher MITM Attack
mitm_operations_double = 2 * (2**16) # 2^16 encryption + 2^16 decryption
print(f"MITM Operations (Double Mini): {mitm_operations_double}")

# c) Exhaustive Key Search (Double Mini)
exhaustive_operations_double = 2**32
print(f"Exhaustive Operations (Double Mini): {exhaustive_operations_double}")

# d) Tradeoff
print("\nMITM Attack Tradeoff:")
print("Speed: MITM is significantly faster than exhaustive search for multiple rounds.")
print("Memory: MITM requires storing intermediate results, increasing memory usage.")
print("Complexity: MITM reduces time complexity from O(2^2n) to O(2^n) for two rounds.")
# Out:
# state: 0000000010101010
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 6
#       4 for i in range(10):
#       5     plaintext = i * 0b1100110011001100
# ----> 6     ciphertext = encrypt(plaintext, key)
#       7     plaintext_ciphertext_pairs.append((plaintext, ciphertext))
#       9 print("Plaintext-Ciphertext Pairs:")
#
# Cell In[3], line 91, in encrypt(plaintext, key)
#      89 Key0, Key1, Key2 = key_expansion(key)
#      90 state = plaintext ^ Key0  # Initial AddRoundKey
# ---> 91 state = encrypt_round1(state, Key1)
#      92 state = encrypt_round2(state, Key2)
#      93 return state
#
# Cell In[3], line 59, in encrypt_round1(state, Key1)
#      58 def encrypt_round1(state, Key1):
# ---> 59     state = substitute(state)
#      60     state = shift(state)
#      61     state = mix(state)
#
# Cell In[3], line 39, in substitute(state, inverse)
#      37 if inverse:
#      38     return inverse_s_box[state]     # Reverse substitution (16-bit constant)
# ---> 39 return s_box[state]
#
# KeyError: 170

# %%
# Mini Block Cipher Implementation and Meet-in-the-Middle Attack

# --- Task 1: Implementing Mini Block Cipher ---

# Key Expansion: Split 16-bit key into Key0, Key1, Key2
def key_expansion(key):
    Key0 = (key >> 8) & 0xFF  # First 8 bits
    Key1 = key & 0xFF        # Next 8 bits
    Key2 = Key0 ^ Key1        # XOR of Key0 and Key1 (example)
    return Key0, Key1, Key2

# Substitution function (example: simple XOR with a constant)
def substitute(state, inverse=False):
    if inverse:
        return state ^ 0b1010101010101010  # Inverse substitution (16-bit constant)
    return state ^ 0b0101010101010101      # Forward substitution (16-bit constant)

# Shift function (example: circular shift left by 4 bits)
def shift(state, inverse=False):
    if inverse:
        return ((state >> 4) | (state << 12)) & 0xFFFF  # Reverse shift (16-bit)
    return ((state << 4) | (state >> 12)) & 0xFFFF      # Forward shift (16-bit)

# Mix function (example: XOR with a constant)
def mix(state, inverse=False):
    if inverse:
        return state ^ 0b1100110011001100  # Inverse mix (16-bit constant)
    return state ^ 0b0011001100110011      # Forward mix (16-bit constant)

# AddRoundKey function (XOR with the round key)
def add_round_key(state, round_key):
    return state ^ round_key

# Encryption Round 1
def encrypt_round1(state, Key1):
    print(f"  Round 1 - Input State: {state:016b}")
    state = substitute(state)
    print(f"  Round 1 - After Substitute: {state:016b}")
    state = shift(state)
    print(f"  Round 1 - After Shift: {state:016b}")
    state = mix(state)
    print(f"  Round 1 - After Mix: {state:016b}")
    state = add_round_key(state, Key1)
    print(f"  Round 1 - After AddRoundKey: {state:016b}")
    return state

# Encryption Round 2
def encrypt_round2(state, Key2):
    print(f"  Round 2 - Input State: {state:016b}")
    state = substitute(state)
    print(f"  Round 2 - After Substitute: {state:016b}")
    state = shift(state)
    print(f"  Round 2 - After Shift: {state:016b}")
    state = add_round_key(state, Key2)
    print(f"  Round 2 - After AddRoundKey: {state:016b}")
    return state

# Decryption Round 2
def decrypt_round2(state, Key2):
    print(f"  Decryption Round 2 - Input State: {state:016b}")
    state = add_round_key(state, Key2)
    print(f"  Decryption Round 2 - After AddRoundKey: {state:016b}")
    state = shift(state, inverse=True)
    print(f"  Decryption Round 2 - After Shift: {state:016b}")
    state = substitute(state, inverse=True)
    print(f"  Decryption Round 2 - After Substitute: {state:016b}")
    return state

# Decryption Round 1
def decrypt_round1(state, Key1):
    print(f"  Decryption Round 1 - Input State: {state:016b}")
    state = add_round_key(state, Key1)
    print(f"  Decryption Round 1 - After AddRoundKey: {state:016b}")
    state = mix(state, inverse=True)
    print(f"  Decryption Round 1 - After Mix: {state:016b}")
    state = shift(state, inverse=True)
    print(f"  Decryption Round 1 - After Shift: {state:016b}")
    state = substitute(state, inverse=True)
    print(f"  Decryption Round 1 - After Substitute: {state:016b}")
    return state

# Full Encryption
def encrypt(plaintext, key):
    Key0, Key1, Key2 = key_expansion(key)
    print(f"Key0: {Key0:08b}, Key1: {Key1:08b}, Key2: {Key2:08b}")
    state = plaintext ^ Key0  # Initial AddRoundKey
    print(f"Initial AddRoundKey: {state:016b}")
    state = encrypt_round1(state, Key1)
    state = encrypt_round2(state, Key2)
    print(f"Final Ciphertext: {state:016b}")
    return state

# Full Decryption
def decrypt(ciphertext, key):
    Key0, Key1, Key2 = key_expansion(key)
    print(f"Key0: {Key0:08b}, Key1: {Key1:08b}, Key2: {Key2:08b}")
    state = decrypt_round2(ciphertext, Key2)
    state = decrypt_round1(state, Key1)
    state = state ^ Key0  # Final AddRoundKey
    print(f"Final Plaintext: {state:016b}")
    return state

# Generate Plaintext-Ciphertext Pairs
key = 0b1010101010101010
plaintext_ciphertext_pairs = []
for i in range(10):
    plaintext = i * 0b1100110011001100
    ciphertext = encrypt(plaintext, key)
    plaintext_ciphertext_pairs.append((plaintext, ciphertext))

print("Plaintext-Ciphertext Pairs:")
for p, c in plaintext_ciphertext_pairs:
    print(f"Plaintext: {p:016b}, Ciphertext: {c:016b}")

# --- Task 2: Meet-in-the-Middle Attack ---

def meet_in_the_middle(plaintext_ciphertext_pairs):
    (plaintext1, ciphertext1), (plaintext2, ciphertext2) = plaintext_ciphertext_pairs[:2] #use the first two pairs.

    forward_table = {}
    for key1 in range(256):  # Key1 is 8 bits
        intermediate = encrypt_round1(plaintext1, key1)
        forward_table[intermediate] = key1

    reverse_table = {}
    for key2 in range(256):  # Key2 is 8 bits
        intermediate = decrypt_round2(ciphertext1, key2)
        if intermediate in forward_table:
            reverse_table.setdefault(intermediate, []).append(key2)

    possible_keys = []
    for intermediate, key1 in forward_table.items():
        if intermediate in reverse_table:
            for key2 in reverse_table[intermediate]:
                # Verify with the second pair
                if encrypt_round2(encrypt_round1(plaintext2, key1), key2) == ciphertext2:
                    possible_keys.append((key1, key2))

    return possible_keys

possible_keys = meet_in_the_middle(plaintext_ciphertext_pairs)
print("\nPossible Key Pairs:")
for k1, k2 in possible_keys:
    print(f"Key1: {k1:08b}, Key2: {k2:08b}")

# --- Task 3: Analysis ---

# a) Key Space
key_space = 2**16
print(f"\nKey Space: {key_space}")

# b) Double Mini Block Cipher MITM Attack
mitm_operations_double = 2 * (2**16) # 2^16 encryption + 2^16 decryption
print(f"MITM Operations (Double Mini): {mitm_operations_double}")

# c) Exhaustive Key Search (Double Mini)
exhaustive_operations_double = 2**32
print(f"Exhaustive Operations (Double Mini): {exhaustive_operations_double}")
# Out:
# Key0: 10101010, Key1: 10101010, Key2: 00000000
# Initial AddRoundKey: 0000000010101010
#   Round 1 - Input State: 0000000010101010
#   Round 1 - After Substitute: 0101010111111111
#   Round 1 - After Shift: 0101111111110101
#   Round 1 - After Mix: 0110110011000110
#   Round 1 - After AddRoundKey: 0110110001101100
#   Round 2 - Input State: 0110110001101100
#   Round 2 - After Substitute: 0011100100111001
#   Round 2 - After Shift: 1001001110010011
#   Round 2 - After AddRoundKey: 1001001110010011
# Final Ciphertext: 1001001110010011
# Key0: 10101010, Key1: 10101010, Key2: 00000000
# Initial AddRoundKey: 1100110001100110
#   Round 1 - Input State: 1100110001100110
#   Round 1 - After Substitute: 1001100100110011
#   Round 1 - After Shift: 1001001100111001
#   Round 1 - After Mix: 1010000000001010
#   Round 1 - After AddRoundKey: 1010000010100000
#   Round 2 - Input State: 1010000010100000
#   Round 2 - After Substitute: 1111010111110101
#   Round 2 - After Shift: 0101111101011111
#   Round 2 - After AddRoundKey: 0101111101011111
# Final Ciphertext: 0101111101011111
# Key0: 10101010, Key1: 10101010, Key2: 00000000
# Initial AddRoundKey: 11001100100110010
#   Round 1 - Input State: 11001100100110010
#   Round 1 - After Substitute: 11100110001100111
#   Round 1 - After Shift: 1100011001111100
#   Round 1 - After Mix: 1111010101001111
#   Round 1 - After AddRoundKey: 1111010111100101
#   Round 2 - Input State: 1111010111100101
#   Round 2 - After Substitute: 1010000010110000
#   Round 2 - After Shift: 0000101100001010
#   Round 2 - After AddRoundKey: 0000101100001010
# Final Ciphertext: 0000101100001010
# Key0: 10101010, Key1: 10101010, Key2: 00000000
# Initial AddRoundKey: 100110011011001110
#   Round 1 - Input State: 100110011011001110
#   Round 1 - After Substitute: 100011001110011011
#   Round 1 - After Shift: 0011100110110011
#   Round 1 - After Mix: 0000101010000000
#   Round 1 - After AddRoundKey: 0000101000101010
#   Round 2 - Input State: 0000101000101010
#   Round 2 - After Substitute: 0101111101111111
#   Round 2 - After Shift: 1111011111110101
#   Round 2 - After AddRoundKey: 1111011111110101
# Final Ciphertext: 1111011111110101
# Key0: 10101010, Key1: 10101010, Key2: 00000000
# Initial AddRoundKey: 110011001110011010
#   Round 1 - Input State: 110011001110011010
#   Round 1 - After Substitute: 110110011011001111
#   Round 1 - After Shift: 0110110011110110
#   Round 1 - After Mix: 0101111111000101
#   Round 1 - After AddRoundKey: 0101111101101111
#   Round 2 - Input State: 0101111101101111
#   Round 2 - After Substitute: 0000101000111010
#   Round 2 - After Shift: 1010001110100000
#   Round 2 - After AddRoundKey: 1010001110100000
# Final Ciphertext: 1010001110100000
# Key0: 10101010, Key1: 10101010, Key2: 00000000
# Initial AddRoundKey: 111111111101010110
#   Round 1 - Input State: 111111111101010110
#   Round 1 - After Substitute: 111010101000000011
#   Round 1 - After Shift: 1010000000111010
#   Round 1 - After Mix: 1001001100001001
#   Round 1 - After AddRoundKey: 1001001110100011
#   Round 2 - Input State: 1001001110100011
#   Round 2 - After Substitute: 1100011011110110
#   Round 2 - After Shift: 0110111101101100
#   Round 2 - After AddRoundKey: 0110111101101100
# Final Ciphertext: 0110111101101100
# Key0: 10101010, Key1: 10101010, Key2: 00000000
# Initial AddRoundKey: 1001100110001100010
#   Round 1 - Input State: 1001100110001100010
#   Round 1 - After Substitute: 1001001100100110111
#   Round 1 - After Shift: 1001001101111001
#   Round 1 - After Mix: 1010000001001010
#   Round 1 - After AddRoundKey: 1010000011100000
#   Round 2 - Input State: 1010000011100000
#   Round 2 - After Substitute: 1111010110110101
#   Round 2 - After Shift: 0101101101011111
#   Round 2 - After AddRoundKey: 0101101101011111
# Final Ciphertext: 0101101101011111
# Key0: 10101010, Key1: 10101010, Key2: 00000000
# Initial AddRoundKey: 1011001100100111110
#   Round 1 - Input State: 1011001100100111110
#   Round 1 - After Substitute: 1011100110001101011
#   Round 1 - After Shift: 1100011011111100
#   Round 1 - After Mix: 1111010111001111
#   Round 1 - After AddRoundKey: 1111010101100101
#   Round 2 - Input State: 1111010101100101
#   Round 2 - After Substitute: 1010000000110000
#   Round 2 - After Shift: 0000001100001010
#   Round 2 - After AddRoundKey: 0000001100001010
# Final Ciphertext: 0000001100001010
# Key0: 10101010, Key1: 10101010, Key2: 00000000
# Initial AddRoundKey: 1100110011011001010
#   Round 1 - Input State: 1100110011011001010
#   Round 1 - After Substitute: 1100011001110011111
#   Round 1 - After Shift: 0011100111110011
#   Round 1 - After Mix: 0000101011000000
#   Round 1 - After AddRoundKey: 0000101001101010
#   Round 2 - Input State: 0000101001101010
#   Round 2 - After Substitute: 0101111100111111
#   Round 2 - After Shift: 1111001111110101
#   Round 2 - After AddRoundKey: 1111001111110101
# Final Ciphertext: 1111001111110101
# Key0: 10101010, Key1: 10101010, Key2: 00000000
# Initial AddRoundKey: 1110011001110000110
#   Round 1 - Input State: 1110011001110000110
#   Round 1 - After Substitute: 1110110011011010011
#   Round 1 - After Shift: 0110110101110110
#   Round 1 - After Mix: 0101111001000101
#   Round 1 - After AddRoundKey: 0101111011101111
#   Round 2 - Input State: 0101111011101111
#   Round 2 - After Substitute: 0000101110111010
#   Round 2 - After Shift: 1011101110100000
#   Round 2 - After AddRoundKey: 1011101110100000
# Final Ciphertext: 1011101110100000
# Plaintext-Ciphertext Pairs:
# Plaintext: 0000000000000000, Ciphertext: 1001001110010011
# Plaintext: 1100110011001100, Ciphertext: 0101111101011111
# Plaintext: 11001100110011000, Ciphertext: 0000101100001010
# Plaintext: 100110011001100100, Ciphertext: 1111011111110101
# Plaintext: 110011001100110000, Ciphertext: 1010001110100000
# Plaintext: 111111111111111100, Ciphertext: 0110111101101100
# Plaintext: 1001100110011001000, Ciphertext: 0101101101011111
# Plaintext: 1011001100110010100, Ciphertext: 0000001100001010
# Plaintext: 1100110011001100000, Ciphertext: 1111001111110101
# Plaintext: 1110011001100101100, Ciphertext: 1011101110100000
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001100110
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001100111
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001100100
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001100101
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001100010
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001100011
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001100000
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001100001
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001101110
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001101111
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001101100
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001101101
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001101010
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001101011
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001101000
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001101001
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001110110
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001110111
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001110100
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001110101
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001110010
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001110011
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001110000
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001110001
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001111110
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001111111
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001111100
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001111101
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001111010
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001111011
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001111000
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001111001
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001000110
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001000111
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001000100
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001000101
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001000010
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001000011
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001000000
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001000001
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001001110
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001001111
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001001100
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001001101
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001001010
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001001011
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001001000
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001001001
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001010110
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001010111
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001010100
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001010101
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001010010
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001010011
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001010000
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001010001
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001011110
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001011111
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001011100
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001011101
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001011010
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001011011
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001011000
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011001011001
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000100110
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000100111
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000100100
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000100101
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000100010
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000100011
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000100000
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000100001
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000101110
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000101111
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000101100
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000101101
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000101010
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000101011
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000101000
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000101001
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000110110
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000110111
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000110100
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000110101
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000110010
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000110011
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000110000
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000110001
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000111110
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000111111
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000111100
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000111101
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000111010
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000111011
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000111000
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000111001
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000000110
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000000111
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000000100
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000000101
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000000010
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000000011
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000000000
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000000001
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000001110
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000001111
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000001100
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000001101
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000001010
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000001011
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000001000
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000001001
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000010110
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000010111
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000010100
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000010101
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000010010
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000010011
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000010000
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000010001
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000011110
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000011111
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000011100
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000011101
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000011010
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000011011
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000011000
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011000011001
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011100110
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011100111
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011100100
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011100101
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011100010
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011100011
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011100000
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011100001
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011101110
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011101111
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011101100
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011101101
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011101010
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011101011
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011101000
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011101001
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011110110
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011110111
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011110100
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011110101
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011110010
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011110011
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011110000
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011110001
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011111110
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011111111
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011111100
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011111101
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011111010
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011111011
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011111000
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011111001
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011000110
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011000111
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011000100
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011000101
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011000010
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011000011
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011000000
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011000001
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011001110
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011001111
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011001100
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011001101
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011001010
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011001011
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011001000
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011001001
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011010110
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011010111
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011010100
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011010101
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011010010
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011010011
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011010000
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011010001
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011011110
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011011111
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011011100
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011011101
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011011010
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011011011
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011011000
#   Round 1 - Input State: 0000000000000000
#   Round 1 - After Substitute: 0101010101010101
#   Round 1 - After Shift: 0101010101010101
#   Round 1 - After Mix: 0110011001100110
#   Round 1 - After AddRoundKey: 0110011011011001
#   Round 1 - Input State: 0000000000000000
# ...
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001100101010
#   Decryption Round 2 - After Shift: 1010100100110010
#   Decryption Round 2 - After Substitute: 0000001110011000
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001100101001
#   Decryption Round 2 - After Shift: 1001100100110010
#   Decryption Round 2 - After Substitute: 0011001110011000
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001100101000
#   Decryption Round 2 - After Shift: 1000100100110010
#   Decryption Round 2 - After Substitute: 0010001110011000
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001100101111
#   Decryption Round 2 - After Shift: 1111100100110010
#   Decryption Round 2 - After Substitute: 0101001110011000
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001100101110
#   Decryption Round 2 - After Shift: 1110100100110010
#   Decryption Round 2 - After Substitute: 0100001110011000
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001100101101
#   Decryption Round 2 - After Shift: 1101100100110010
#   Decryption Round 2 - After Substitute: 0111001110011000
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001100101100
#   Decryption Round 2 - After Shift: 1100100100110010
#   Decryption Round 2 - After Substitute: 0110001110011000
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101010011
#   Decryption Round 2 - After Shift: 0011100100110101
#   Decryption Round 2 - After Substitute: 1001001110011111
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101010010
#   Decryption Round 2 - After Shift: 0010100100110101
#   Decryption Round 2 - After Substitute: 1000001110011111
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101010001
#   Decryption Round 2 - After Shift: 0001100100110101
#   Decryption Round 2 - After Substitute: 1011001110011111
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101010000
#   Decryption Round 2 - After Shift: 0000100100110101
#   Decryption Round 2 - After Substitute: 1010001110011111
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101010111
#   Decryption Round 2 - After Shift: 0111100100110101
#   Decryption Round 2 - After Substitute: 1101001110011111
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101010110
#   Decryption Round 2 - After Shift: 0110100100110101
#   Decryption Round 2 - After Substitute: 1100001110011111
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101010101
#   Decryption Round 2 - After Shift: 0101100100110101
#   Decryption Round 2 - After Substitute: 1111001110011111
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101010100
#   Decryption Round 2 - After Shift: 0100100100110101
#   Decryption Round 2 - After Substitute: 1110001110011111
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101011011
#   Decryption Round 2 - After Shift: 1011100100110101
#   Decryption Round 2 - After Substitute: 0001001110011111
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101011010
#   Decryption Round 2 - After Shift: 1010100100110101
#   Decryption Round 2 - After Substitute: 0000001110011111
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101011001
#   Decryption Round 2 - After Shift: 1001100100110101
#   Decryption Round 2 - After Substitute: 0011001110011111
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101011000
#   Decryption Round 2 - After Shift: 1000100100110101
#   Decryption Round 2 - After Substitute: 0010001110011111
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101011111
#   Decryption Round 2 - After Shift: 1111100100110101
#   Decryption Round 2 - After Substitute: 0101001110011111
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101011110
#   Decryption Round 2 - After Shift: 1110100100110101
#   Decryption Round 2 - After Substitute: 0100001110011111
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101011101
#   Decryption Round 2 - After Shift: 1101100100110101
#   Decryption Round 2 - After Substitute: 0111001110011111
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101011100
#   Decryption Round 2 - After Shift: 1100100100110101
#   Decryption Round 2 - After Substitute: 0110001110011111
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101000011
#   Decryption Round 2 - After Shift: 0011100100110100
#   Decryption Round 2 - After Substitute: 1001001110011110
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101000010
#   Decryption Round 2 - After Shift: 0010100100110100
#   Decryption Round 2 - After Substitute: 1000001110011110
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101000001
#   Decryption Round 2 - After Shift: 0001100100110100
#   Decryption Round 2 - After Substitute: 1011001110011110
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101000000
#   Decryption Round 2 - After Shift: 0000100100110100
#   Decryption Round 2 - After Substitute: 1010001110011110
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101000111
#   Decryption Round 2 - After Shift: 0111100100110100
#   Decryption Round 2 - After Substitute: 1101001110011110
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101000110
#   Decryption Round 2 - After Shift: 0110100100110100
#   Decryption Round 2 - After Substitute: 1100001110011110
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101000101
#   Decryption Round 2 - After Shift: 0101100100110100
#   Decryption Round 2 - After Substitute: 1111001110011110
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101000100
#   Decryption Round 2 - After Shift: 0100100100110100
#   Decryption Round 2 - After Substitute: 1110001110011110
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101001011
#   Decryption Round 2 - After Shift: 1011100100110100
#   Decryption Round 2 - After Substitute: 0001001110011110
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101001010
#   Decryption Round 2 - After Shift: 1010100100110100
#   Decryption Round 2 - After Substitute: 0000001110011110
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101001001
#   Decryption Round 2 - After Shift: 1001100100110100
#   Decryption Round 2 - After Substitute: 0011001110011110
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101001000
#   Decryption Round 2 - After Shift: 1000100100110100
#   Decryption Round 2 - After Substitute: 0010001110011110
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101001111
#   Decryption Round 2 - After Shift: 1111100100110100
#   Decryption Round 2 - After Substitute: 0101001110011110
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101001110
#   Decryption Round 2 - After Shift: 1110100100110100
#   Decryption Round 2 - After Substitute: 0100001110011110
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101001101
#   Decryption Round 2 - After Shift: 1101100100110100
#   Decryption Round 2 - After Substitute: 0111001110011110
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101001100
#   Decryption Round 2 - After Shift: 1100100100110100
#   Decryption Round 2 - After Substitute: 0110001110011110
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101110011
#   Decryption Round 2 - After Shift: 0011100100110111
#   Decryption Round 2 - After Substitute: 1001001110011101
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101110010
#   Decryption Round 2 - After Shift: 0010100100110111
#   Decryption Round 2 - After Substitute: 1000001110011101
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101110001
#   Decryption Round 2 - After Shift: 0001100100110111
#   Decryption Round 2 - After Substitute: 1011001110011101
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101110000
#   Decryption Round 2 - After Shift: 0000100100110111
#   Decryption Round 2 - After Substitute: 1010001110011101
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101110111
#   Decryption Round 2 - After Shift: 0111100100110111
#   Decryption Round 2 - After Substitute: 1101001110011101
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101110110
#   Decryption Round 2 - After Shift: 0110100100110111
#   Decryption Round 2 - After Substitute: 1100001110011101
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101110101
#   Decryption Round 2 - After Shift: 0101100100110111
#   Decryption Round 2 - After Substitute: 1111001110011101
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101110100
#   Decryption Round 2 - After Shift: 0100100100110111
#   Decryption Round 2 - After Substitute: 1110001110011101
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101111011
#   Decryption Round 2 - After Shift: 1011100100110111
#   Decryption Round 2 - After Substitute: 0001001110011101
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101111010
#   Decryption Round 2 - After Shift: 1010100100110111
#   Decryption Round 2 - After Substitute: 0000001110011101
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101111001
#   Decryption Round 2 - After Shift: 1001100100110111
#   Decryption Round 2 - After Substitute: 0011001110011101
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101111000
#   Decryption Round 2 - After Shift: 1000100100110111
#   Decryption Round 2 - After Substitute: 0010001110011101
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101111111
#   Decryption Round 2 - After Shift: 1111100100110111
#   Decryption Round 2 - After Substitute: 0101001110011101
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101111110
#   Decryption Round 2 - After Shift: 1110100100110111
#   Decryption Round 2 - After Substitute: 0100001110011101
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101111101
#   Decryption Round 2 - After Shift: 1101100100110111
#   Decryption Round 2 - After Substitute: 0111001110011101
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101111100
#   Decryption Round 2 - After Shift: 1100100100110111
#   Decryption Round 2 - After Substitute: 0110001110011101
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101100011
#   Decryption Round 2 - After Shift: 0011100100110110
#   Decryption Round 2 - After Substitute: 1001001110011100
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101100010
#   Decryption Round 2 - After Shift: 0010100100110110
#   Decryption Round 2 - After Substitute: 1000001110011100
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101100001
#   Decryption Round 2 - After Shift: 0001100100110110
#   Decryption Round 2 - After Substitute: 1011001110011100
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101100000
#   Decryption Round 2 - After Shift: 0000100100110110
#   Decryption Round 2 - After Substitute: 1010001110011100
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101100111
#   Decryption Round 2 - After Shift: 0111100100110110
#   Decryption Round 2 - After Substitute: 1101001110011100
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101100110
#   Decryption Round 2 - After Shift: 0110100100110110
#   Decryption Round 2 - After Substitute: 1100001110011100
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101100101
#   Decryption Round 2 - After Shift: 0101100100110110
#   Decryption Round 2 - After Substitute: 1111001110011100
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101100100
#   Decryption Round 2 - After Shift: 0100100100110110
#   Decryption Round 2 - After Substitute: 1110001110011100
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101101011
#   Decryption Round 2 - After Shift: 1011100100110110
#   Decryption Round 2 - After Substitute: 0001001110011100
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101101010
#   Decryption Round 2 - After Shift: 1010100100110110
#   Decryption Round 2 - After Substitute: 0000001110011100
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101101001
#   Decryption Round 2 - After Shift: 1001100100110110
#   Decryption Round 2 - After Substitute: 0011001110011100
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101101000
#   Decryption Round 2 - After Shift: 1000100100110110
#   Decryption Round 2 - After Substitute: 0010001110011100
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101101111
#   Decryption Round 2 - After Shift: 1111100100110110
#   Decryption Round 2 - After Substitute: 0101001110011100
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101101110
#   Decryption Round 2 - After Shift: 1110100100110110
#   Decryption Round 2 - After Substitute: 0100001110011100
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101101101
#   Decryption Round 2 - After Shift: 1101100100110110
#   Decryption Round 2 - After Substitute: 0111001110011100
#   Decryption Round 2 - Input State: 1001001110010011
#   Decryption Round 2 - After AddRoundKey: 1001001101101100
#   Decryption Round 2 - After Shift: 1100100100110110
#   Decryption Round 2 - After Substitute: 0110001110011100
#
# Possible Key Pairs:
#
# Key Space: 65536
# MITM Operations (Double Mini): 131072
# Exhaustive Operations (Double Mini): 4294967296
